# %%
import pandas as pd
import pygal
import numpy as np
from sklearn.cluster import DBSCAN

# %%
from IPython.display import display, HTML
base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %%
dataFrame = pd.read_json(r"C:\Users\GEORGIE\Dropbox\Research Thesis\RESEARCH-PROJECT\DBScan-Final\ContactTracingDBSCan\actual.json")
dataFrame.head()
# Out:
#     id                         name            transdate       epoch  room  \
# 0  471              Optina, Charles  2023-05-02 11:08:57  1682996937   205
# 1  472  Napallacan, Frienz Marinino  2023-05-02 11:24:07  1682997847   205
# 2  473               Gesite, George  2023-05-02 10:05:07  1682993107     9
# 3  474            Gohil, Robert Kin  2023-05-02 10:20:37  1682994037     9
# 4  475  Napallacan, Frienz Marinino  2023-05-02 16:18:17  1683015497     1
#
#       temp    course
# 0  37.15 C  BSCPE 1B
# 1  36.31 C  BSCPE 1B
# 2  36.48 C  BSCPE 4A
# 3  36.44 C  BSCPE 4A
# 4  36.09 C  BSCPE 1B

# %%
disp_dict = {}
for index, row in dataFrame.iterrows():
    if row['name'] not in disp_dict.keys():
        disp_dict[row['name']] = [(row['room'], row['epoch'])]
    else:
        disp_dict[row['name']].append((row['room'], row['epoch']))
xy_chart = pygal.XY(stroke=False)
[xy_chart.add(k,v) for k,v in sorted(disp_dict.items())]
display(HTML(base_html.format(rendered_chart=xy_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-05-04--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa{background-color:rgba(249,249,249,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa path,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa line,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa rect,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .graph{fill:rgba(0,0,0,.87)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa text.no_data{fill:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .title{fill:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .legends .legend text{fill:rgba(0,0,0,.87)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis .line{stroke:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis text.major{fill:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis.y .guides:hover .guide.line,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .line-graph .axis.x .guides:hover .guide.line,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .stackedline-graph .axis.x .guides:hover .guide.line,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .ci{stroke:rgba(0,0,0,.87)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .reactive.active,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .ci .reactive.active{stroke-width:1.5}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .series text{fill:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .tooltip .value{font-size:1.5em}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .bound{font-size:.5em}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-0,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-1,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-2,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-2 a:visited{stroke:#009688;fill:#009688}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-3,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .color-4,#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa . ...
# #chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa text.no_data{text-anchor:middle}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .guide.line{fill:none}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .centered{text-anchor:middle}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .title{text-anchor:middle}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .legends .legend text{fill-opacity:1}#chart-4e86ccf3-ebf4-46e5-bcfa-dfc08339c7aa .axis.x text{text-anchor:middle}#chart-4e86ccf3-ebf4-46e5-

# %%
safe_distance = 0.3 #radial distance of 1 room (inside 1 room)
model = DBSCAN(eps=safe_distance, min_samples=2, metric='haversine').fit(dataFrame[['room', 'epoch']])
core_samples_mask = np.zeros_like(model.labels_, dtype=bool)
core_samples_mask[model.core_sample_indices_] = True
labels = model.labels_
dataFrame['Cluster'] = model.labels_.tolist()

# %%
disp_dict_clust = {}
for index, row in dataFrame.iterrows():
    if row['Cluster'] not in disp_dict_clust.keys():
        disp_dict_clust[row['Cluster']] = [(row['room'], row['epoch'])]
    else:
        disp_dict_clust[row['Cluster']].append((row['room'], row['epoch']))
print(len(disp_dict_clust.keys()))
from pygal.style import LightenStyle
dark_lighten_style = LightenStyle('#1E90FF')
xy_chart = pygal.XY(stroke=False, style=dark_lighten_style)
[xy_chart.add(str(k),v) for k,v in disp_dict_clust.items()]
display(HTML(base_html.format(rendered_chart=xy_chart.render(is_unicode=True))))
# Out:
# 7
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-05-03--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129{background-color:rgba(249,249,249,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 path,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 line,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 rect,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .graph{fill:rgba(0,0,0,.87)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 text.no_data{fill:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .title{fill:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis .line{stroke:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis text.major{fill:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis.y .guides:hover .guide.line,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .line-graph .axis.x .guides:hover .guide.line,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .ci{stroke:rgba(0,0,0,.87)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .reactive.active,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .ci .reactive.active{stroke-width:1.5}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .series text{fill:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .tooltip .value{font-size:1.5em}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .bound{font-size:.5em}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-0,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-0 a:visited{stroke:#1e90ff;fill:#1e90ff}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-1,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-1 a:visited{stroke:#3a9eff;fill:#3a9eff}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-2,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-2 a:visited{stroke:#57acff;fill:#57acff}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-3,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-3 a:visited{stroke:#73baff;fill:#73baff}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .color-4,#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 . ...
# #chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 text.no_data{text-anchor:middle}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .guide.line{fill:none}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .centered{text-anchor:middle}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .title{text-anchor:middle}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .legends .legend text{fill-opacity:1}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis.x text{text-anchor:middle}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis.y text{text-anchor:end}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis.y text[transform].backwards{text-anchor:start}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis.y2 text{text-anchor:start}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis.y2 text[transform].backwards{text-anchor:end}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-d7f8e4cb-3938-47e5-aad3-1d14e5eba129 .axis .major.guide.line{str

# %%
def contactTracing(dataFrame, inputName):
    #Check if name is valid
    assert (inputName in dataFrame['name'].tolist()), "name Doesn't exist"
    #Social distance
    safe_distance = 0.3 #6 feets in kilometers
    #Apply model, in case of larger dataset or noisy one, increase min_samples
    model = DBSCAN(eps=safe_distance, min_samples=2, metric='haversine').fit(dataFrame[['room', 'epoch']])
    #Get clusters found bt the algorithm 
    labels = model.labels_
    #Add the clusters to the dataframe
    dataFrame['Cluster'] = model.labels_.tolist()
    #Get the clusters the inputName is a part of
    inputNameClusters = set()
    for i in range(len(dataFrame)):
        if dataFrame['name'][i] == inputName:
            inputNameClusters.add(dataFrame['Cluster'][i])
   #Get people who are in the same cluster as the inputName              
    infected = set()
    for cluster in inputNameClusters:
        if cluster != -1: #as long as it is not the -1 cluster
            namesInCluster = dataFrame.loc[dataFrame['Cluster'] == cluster, 'name'] #Get all names in the cluster
            for i in range(len(namesInCluster)):
              #locate each name on the cluster
                name = namesInCluster.iloc[i]
                if name != inputName: #Don't want to add the input to the results
                    infected.add(name)
    print("Potential infections are:",*infected,sep="\n" )

# %%
contactTracing(dataFrame, inputName = 'Lampios, Claire Ann')
# Out:
# Potential infections are:
