# %%
import pandas as pd
import pygal
import numpy as np
from sklearn.cluster import DBSCAN

# %%
from IPython.display import display, HTML
base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %%
dataFrame = pd.read_json(r"C:\Users\GEORGIE\Dropbox\Research Thesis\RESEARCH-PROJECT\DBSCAN\270423.json")
dataFrame.head()
# Out:
#     id              name            transdate       epoch  room       temp  \
# 0  103      Instructor D  2023-04-23 16:43:48  1682268227   205  33.43 C\r
# 1  104  George Jr Gesite  2023-04-24 20:51:53  1682369513   205  34.25 C\r
# 2  105  George Jr Gesite  2023-04-24 20:56:26  1682369786   203  36.25 C\r
# 3  106  Robert Kin Gohil  2023-04-24 20:57:28  1682369847   210  35.55 C\r
# 4  107  Robert Kin Gohil  2023-04-24 21:10:02  1682370601   203  35.37 C\r
#
#      course
# 0      BSCE
# 1  BSCPE 4A
# 2  BSCPE 4A
# 3  BSCPE 4A
# 4  BSCPE 4A

# %%
disp_dict = {}
for index, row in dataFrame.iterrows():
    if row['name'] not in disp_dict.keys():
        disp_dict[row['name']] = [(row['room'], row['epoch'])]
    else:
        disp_dict[row['name']].append((row['room'], row['epoch']))
xy_chart = pygal.XY(stroke=False)
[xy_chart.add(k,v) for k,v in sorted(disp_dict.items())]
display(HTML(base_html.format(rendered_chart=xy_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-da606ca8-920f-400e-a6df-afa15284b51d" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-04-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-da606ca8-920f-400e-a6df-afa15284b51d{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-da606ca8-920f-400e-a6df-afa15284b51d .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-da606ca8-920f-400e-a6df-afa15284b51d .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-da606ca8-920f-400e-a6df-afa15284b51d .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-da606ca8-920f-400e-a6df-afa15284b51d .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-da606ca8-920f-400e-a6df-afa15284b51d .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-da606ca8-920f-400e-a6df-afa15284b51d .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-da606ca8-920f-400e-a6df-afa15284b51d .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-da606ca8-920f-400e-a6df-afa15284b51d text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-da606ca8-920f-400e-a6df-afa15284b51d{background-color:rgba(249,249,249,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d path,#chart-da606ca8-920f-400e-a6df-afa15284b51d line,#chart-da606ca8-920f-400e-a6df-afa15284b51d rect,#chart-da606ca8-920f-400e-a6df-afa15284b51d circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-da606ca8-920f-400e-a6df-afa15284b51d .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .graph{fill:rgba(0,0,0,.87)}#chart-da606ca8-920f-400e-a6df-afa15284b51d text.no_data{fill:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .title{fill:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .legends .legend text{fill:rgba(0,0,0,.87)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .axis .line{stroke:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .axis text.major{fill:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .axis.y .guides:hover .guide.line,#chart-da606ca8-920f-400e-a6df-afa15284b51d .line-graph .axis.x .guides:hover .guide.line,#chart-da606ca8-920f-400e-a6df-afa15284b51d .stackedline-graph .axis.x .guides:hover .guide.line,#chart-da606ca8-920f-400e-a6df-afa15284b51d .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-da606ca8-920f-400e-a6df-afa15284b51d .ci{stroke:rgba(0,0,0,.87)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .reactive.active,#chart-da606ca8-920f-400e-a6df-afa15284b51d .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-da606ca8-920f-400e-a6df-afa15284b51d .ci .reactive.active{stroke-width:1.5}#chart-da606ca8-920f-400e-a6df-afa15284b51d .series text{fill:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-da606ca8-920f-400e-a6df-afa15284b51d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-da606ca8-920f-400e-a6df-afa15284b51d .tooltip .value{font-size:1.5em}#chart-da606ca8-920f-400e-a6df-afa15284b51d .bound{font-size:.5em}#chart-da606ca8-920f-400e-a6df-afa15284b51d .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-da606ca8-920f-400e-a6df-afa15284b51d .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-da606ca8-920f-400e-a6df-afa15284b51d .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-0,#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-1,#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-2,#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-2 a:visited{stroke:#009688;fill:#009688}#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-3,#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-da606ca8-920f-400e-a6df-afa15284b51d .color-4,#chart-da606ca8-920f-400e-a6df-afa15284b51d . ...

# %%
safe_distance = 0.4 #radial distance of 1 room (inside 1 room)
model = DBSCAN(eps=safe_distance, min_samples=2, metric='haversine').fit(dataFrame[['room', 'epoch']])
core_samples_mask = np.zeros_like(model.labels_, dtype=bool)
core_samples_mask[model.core_sample_indices_] = True
labels = model.labels_
dataFrame['Cluster'] = model.labels_.tolist()

# %%
disp_dict_clust = {}
for index, row in dataFrame.iterrows():
    if row['Cluster'] not in disp_dict_clust.keys():
        disp_dict_clust[row['Cluster']] = [(row['room'], row['epoch'])]
    else:
        disp_dict_clust[row['Cluster']].append((row['room'], row['epoch']))
print(len(disp_dict_clust.keys()))
from pygal.style import LightenStyle
dark_lighten_style = LightenStyle('#1E90FF')
xy_chart = pygal.XY(stroke=False, style=dark_lighten_style)
[xy_chart.add(str(k),v) for k,v in disp_dict_clust.items()]
display(HTML(base_html.format(rendered_chart=xy_chart.render(is_unicode=True))))
# Out:
# 9
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-04-27--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3{background-color:rgba(249,249,249,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 path,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 line,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 rect,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .graph{fill:rgba(0,0,0,.87)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 text.no_data{fill:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .title{fill:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis .line{stroke:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis text.major{fill:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis.y .guides:hover .guide.line,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .line-graph .axis.x .guides:hover .guide.line,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .ci{stroke:rgba(0,0,0,.87)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .reactive.active,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .ci .reactive.active{stroke-width:1.5}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .series text{fill:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .tooltip .value{font-size:1.5em}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .bound{font-size:.5em}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-0,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-0 a:visited{stroke:#1e90ff;fill:#1e90ff}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-1,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-1 a:visited{stroke:#3a9eff;fill:#3a9eff}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-2,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-2 a:visited{stroke:#57acff;fill:#57acff}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-3,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-3 a:visited{stroke:#73baff;fill:#73baff}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .color-4,#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 . ...
# #chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 text.no_data{text-anchor:middle}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .guide.line{fill:none}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .centered{text-anchor:middle}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .title{text-anchor:middle}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .legends .legend text{fill-opacity:1}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis.x text{text-anchor:middle}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-bca1ff71-ea0b-4c95-bfe2-e402c2c104f3 .axis.y t

# %%
def contactTracing(dataFrame, inputName):
    #Check if name is valid
    assert (inputName in dataFrame['name'].tolist()), "name Doesn't exist"
    #Social distance
    safe_distance = 0.3 #6 feets in kilometers
    #Apply model, in case of larger dataset or noisy one, increase min_samples
    model = DBSCAN(eps=safe_distance, min_samples=2, metric='haversine').fit(dataFrame[['room', 'epoch']])
    #Get clusters found bt the algorithm 
    labels = model.labels_
    #Add the clusters to the dataframe
    dataFrame['Cluster'] = model.labels_.tolist()
    #Get the clusters the inputName is a part of
    inputNameClusters = set()
    for i in range(len(dataFrame)):
        if dataFrame['name'][i] == inputName:
            inputNameClusters.add(dataFrame['Cluster'][i])
   #Get people who are in the same cluster as the inputName              
    infected = set()
    for cluster in inputNameClusters:
        if cluster != -1: #as long as it is not the -1 cluster
            namesInCluster = dataFrame.loc[dataFrame['Cluster'] == cluster, 'name'] #Get all names in the cluster
            for i in range(len(namesInCluster)):
              #locate each name on the cluster
                name = namesInCluster.iloc[i]
                if name != inputName: #Don't want to add the input to the results
                    infected.add(name)
    print("Potential infections are:",*infected,sep="\n" )

# %%
contactTracing(dataFrame, inputName = 'Lampios, Claire Ann')
# Out:
# Potential infections are:
