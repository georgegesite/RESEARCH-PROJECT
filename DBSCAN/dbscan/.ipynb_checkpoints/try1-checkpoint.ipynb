# %%
import pandas as pd
import pygal
import numpy as np
from sklearn.cluster import DBSCAN

# %%
from IPython.display import display, HTML
base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %%
dataFrame = pd.read_json(r"C:\Users\GEORGIE\Downloads\MOCK2.json")
dataFrame.head()
# Out:
#         user   datetime   Longitude   Latitude
# 0      Corby 2018-04-18  -79.219738  -7.791120
# 1  Maribelle 2018-04-18   20.872854  37.758294
# 2     Anders 2018-04-18   20.370037  54.925782
# 3    Margery 2018-04-18  107.411996  37.595794
# 4     Caresa 2018-04-18  113.494320  23.086181

# %%
disp_dict = {}
for index, row in dataFrame.iterrows():
    if row['user'] not in disp_dict.keys():
        disp_dict[row['user']] = [(row['Latitude'], row['Longitude'])]
    else:
        disp_dict[row['user']].append((row['Latitude'], row['Longitude']))
xy_chart = pygal.XY(stroke=False)
[xy_chart.add(k,v) for k,v in sorted(disp_dict.items())]
display(HTML(base_html.format(rendered_chart=xy_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2022-07-28--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68{background-color:rgba(249,249,249,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 path,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 line,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 rect,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .graph{fill:rgba(0,0,0,.87)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 text.no_data{fill:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .title{fill:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .axis .line{stroke:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .axis text.major{fill:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .axis.y .guides:hover .guide.line,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .line-graph .axis.x .guides:hover .guide.line,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .ci{stroke:rgba(0,0,0,.87)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .reactive.active,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .ci .reactive.active{stroke-width:1.5}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .series text{fill:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .tooltip .value{font-size:1.5em}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .bound{font-size:.5em}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-0,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-1,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-2,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-3,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 .color-4,#chart-75ca9e9e-ac89-469d-8428-ec4aedf20e68 . ...

# %%
safe_distance = 0.0018288 # a radial distance of 6 feet in kilometers
model = DBSCAN(eps=safe_distance, min_samples=2, metric='haversine').fit(dataFrame[['Latitude', 'Longitude']])
core_samples_mask = np.zeros_like(model.labels_, dtype=bool)
core_samples_mask[model.core_sample_indices_] = True
labels = model.labels_
dataFrame['Cluster'] = model.labels_.tolist()

# %%
disp_dict_clust = {}
for index, row in dataFrame.iterrows():
    if row['Cluster'] not in disp_dict_clust.keys():
        disp_dict_clust[row['Cluster']] = [(row['Latitude'], row['Longitude'])]
    else:
        disp_dict_clust[row['Cluster']].append((row['Latitude'], row['Longitude']))
print(len(disp_dict_clust.keys()))
from pygal.style import LightenStyle
dark_lighten_style = LightenStyle('#F35548')
xy_chart = pygal.XY(stroke=False, style=dark_lighten_style)
[xy_chart.add(str(k),v) for k,v in disp_dict_clust.items()]
display(HTML(base_html.format(rendered_chart=xy_chart.render(is_unicode=True))))
# Out:
# 1
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-1ddf3971-b84a-462b-8f08-a4d4a875882d" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2022-07-28--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-1ddf3971-b84a-462b-8f08-a4d4a875882d{background-color:rgba(249,249,249,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d path,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d rect,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .graph{fill:rgba(0,0,0,.87)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d text.no_data{fill:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .title{fill:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .legends .legend text{fill:rgba(0,0,0,.87)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis .line{stroke:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis text.major{fill:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.y .guides:hover .guide.line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .line-graph .axis.x .guides:hover .guide.line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .stackedline-graph .axis.x .guides:hover .guide.line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .ci{stroke:rgba(0,0,0,.87)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .reactive.active,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .ci .reactive.active{stroke-width:1.5}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .series text{fill:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .tooltip .label{fill:rgba(0,0,0,.87)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .tooltip .value{font-size:1.5em}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .bound{font-size:.5em}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .color-0,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .color-0 a:visited{stroke:#f35548;fill:#f35548}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .text-overlay .color-0 text{fill:black}
# #chart-1ddf3971-b84a-462b-8f08-a4d4a875882d text.no_data{text-anchor:middle}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .guide.line{fill:none}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .centered{text-anchor:middle}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .title{text-anchor:middle}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .legends .legend text{fill-opacity:1}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.x text{text-anchor:middle}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.x:not(.web) text[transform]{text-anchor:start}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.y text{text-anchor:end}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.y text[transform].backwards{text-anchor:start}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.y2 text{text-anchor:start}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.y2 text[transform].backwards{text-anchor:end}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .horizontal .axis.y .guide.line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .horizontal .axis.y2 .guide.line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .vertical .axis.x .guide.line{opacity:0}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .horizontal .axis.always_show .guide.line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.y .guides:hover .guide.line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.y2 .guides:hover .guide.line,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis.x .guides:hover .guide.line{opacity:1}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .axis .guides:hover text{opacity:1}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .nofill{fill:none}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .subtle-fill{fill-opacity:.2}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .dot.active{stroke-width:5px}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .dot.negative{fill:transparent}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d text,#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d tspan{stroke:none !important}#chart-1ddf3971-b84a-462b-8f08-a4d4a875882d .series text.active{opacity:1}#c

# %%
inputName = "Dave"
inputNameClusters = set()
for i in range(len(dataFrame)):
    if dataFrame['user'][i] == inputName:
        inputNameClusters.add(dataFrame['Cluster'][i])

# %%
infected = set()
for cluster in inputNameClusters:
    if cluster != -1:
        namesInCluster = dataFrame.loc[dataFrame['Cluster'] == cluster, 'user']
        for i in range(len(namesInCluster)):
            name = namesInCluster.iloc[i]
            if name != inputName:
                infected.add(name)
